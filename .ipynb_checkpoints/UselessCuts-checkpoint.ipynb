# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
plt.style.use('ggplot')

# %%
score = np.array([[],[]])
for x in np.round(np.linspace(0,10,40),1):
    print(x)
    dataCrab = pd.read_pickle('data/theta-cuts/dataCrab'+str(x))
    print(dataCrab)
    X_train,X_test, y_train, y_test = train_test_split(dataCrab.drop('label',axis=1), dataCrab.label)
    Tree = RandomForestClassifier(random_state=0, max_depth=14, 
        n_estimators=200, n_jobs=20,verbose=1)
    Tree.fit(X_train, y_train)
    score = np.append(score, [[Tree.score(X_train,y_train)],[Tree.score(X_test,y_test)]], axis=1)
# Out:
# 0.0
#         conc_core  concentration_one_pixel  concentration_two_pixel   leakage  \
# 0        0.228827                 0.176404                 0.323771  0.000000
# 1        0.420531                 0.157286                 0.302104  0.000000
# 2        0.400117                 0.109597                 0.186532  0.000000
# 3             NaN                      NaN                      NaN       NaN
# 4             NaN                      NaN                      NaN       NaN
# 5             NaN                      NaN                      NaN       NaN
# 6             NaN                      NaN                      NaN       NaN
# 7        0.492318                 0.114773                 0.222401  0.000000
# 8             NaN                      NaN                      NaN       NaN
# 9        0.365508                 0.098089                 0.185016  0.000000
# 10       0.378119                 0.107935                 0.201456  0.000000
# 11       0.422665                 0.099258                 0.197440  0.000000
# 12            NaN                      NaN                      NaN       NaN
# 13       0.444757                 0.256865                 0.366648  0.000000
# 14            NaN                      NaN                      NaN       NaN
# 15            NaN                      NaN                      NaN       NaN
# 16            NaN                      NaN                      NaN       NaN
# 17            NaN                      NaN                      NaN       NaN
# 18            NaN                      NaN                      NaN       NaN
# 19            NaN                      NaN                      NaN       NaN
# 20       0.300158                 0.160729                 0.275607  0.000000
# 21            NaN                      NaN                      NaN       NaN
# 22       0.327801                 0.097120                 0.189760  0.000000
# 23       0.594063                 0.174208                 0.326685  0.000000
# 24       0.422554                 0.122853                 0.211577  0.000000
# 25       0.362746                 0.056173                 0.103408  0.068116
# 26       0.410920                 0.176774                 0.351782  0.000000
# 27            NaN                      NaN                      NaN       NaN
# 28       0.330203                 0.101162                 0.189773  0.000000
# 29       0.359497                 0.142045                 0.243573  0.000000
# ...           ...                      ...                      ...       ...
# 749970        NaN                      NaN                      NaN       NaN
# 749971        NaN                      NaN                      NaN       NaN
# 749972        NaN                      NaN                      NaN       NaN
# 749973        NaN                      NaN                      NaN       NaN
# 749974        NaN                      NaN                      NaN       NaN
# 749975        NaN                      NaN                      NaN       NaN
# 749976        NaN                      NaN                      NaN       NaN
# 749977        NaN                      NaN                      NaN       NaN
# 749978        NaN                      NaN                      NaN       NaN
# 749979        NaN                      NaN                      NaN       NaN
# 749980        NaN                      NaN                      NaN       NaN
# 749981        NaN                      NaN                      NaN       NaN
# 749982        NaN                      NaN                      NaN       NaN
# 749983        NaN                      NaN                      NaN       NaN
# 749984        NaN                      NaN                      NaN       NaN
# 749985        NaN                      NaN                      NaN       NaN
# 749986        NaN                      NaN                      NaN       NaN
# 749987        NaN                      NaN                      NaN       NaN
# 749988        NaN                      NaN                      NaN       NaN
# 749989        NaN                      NaN                      NaN       NaN
# 749987       NaN         NaN       NaN          NaN                  NaN
# 749988       NaN         NaN       NaN          NaN                  NaN
# 749989       NaN         NaN       NaN          NaN                  NaN
# 749990       NaN         NaN       NaN          NaN                  NaN
# 749991       NaN         NaN       NaN          NaN                  NaN
# 749992       NaN         NaN       NaN          NaN                  NaN
# 749993       NaN         NaN       NaN          NaN                  NaN
# 749994       NaN         NaN       NaN          NaN                  NaN
# 749995       NaN         NaN       NaN          NaN                  NaN
# 749996       NaN         NaN       NaN          NaN                  NaN
# 749997       NaN         NaN       NaN          NaN                  NaN
# 749998       NaN         NaN       NaN          NaN                  NaN
# 749999       NaN         NaN       NaN          NaN                  NaN
#
#         ph_charge_shower_max  ...    leakage2         size      width  \
# 0                  13.225965  ...    0.000000    82.913793   6.790580
# 1                  11.147744  ...    0.649940    61.466865   6.009669
# 2                  31.346850  ...    0.733860   215.080250   7.229127
# 3                        NaN  ...    0.000000    85.220307   7.078917
# 4                        NaN  ...    0.000000   166.065114   5.505444
# 5                        NaN  ...    0.011979   630.733442  13.195658
# 6                        NaN  ...    0.000000    84.778775   6.138170
# 7                  16.399794  ...    0.201859   208.166421   8.664220
# 8                        NaN  ...    0.000000   154.251099   5.503445
# 9                  11.898325  ...    0.420737   162.536120   6.637941
# 10                 12.297828  ...    0.000000   690.186085  15.979153
# 11                 32.408155  ...    0.000000   661.059443   9.975072
# 12                       NaN  ...    0.000000   101.594881   5.770937
# 13                 21.385508  ...    0.000000  1430.990051  13.537254
# 14                       NaN  ...    0.029623  3376.866942  20.568758
# 15                       NaN  ...    0.195761  1069.497312  15.592307
# 16                       NaN  ...    0.208898   251.078954  11.464213
# 17                       NaN  ...    0.000000   161.470729   7.713819
# 18                       NaN  ...    0.744926    82.386065   6.436760
# 19                       NaN  ...    0.336328   325.073321   8.296284
# 20                 12.971736  ...    0.003742  1860.704398  22.018512
# 21                       NaN  ...    0.000000    77.211754   4.363177
# 22                 10.980275  ...    0.000000   129.951389   5.757197
# 23                 17.323896  ...    0.057626  1101.089099  12.769694
# 24                 17.329949  ...    0.000000   218.288806   6.576842
# 25                 25.398696  ...    0.577502   374.258316   9.033410
# 26                 17.767788  ...    0.000000    75.282079   7.030405
# 27                       NaN  ...    0.017303   268.289977  14.090762
# 28                 17.564001  ...    0.729876    75.211990   8.169007
# 29                 18.038159  ...    0.132353  1321.660752  16.797993
# ...                      ...  ...         ...          ...        ...
# 749970                   NaN  ...    0.475134   638.647525  13.836539
# 749971                   NaN  ...    0.000000   327.319786   9.079350
# 749972                   NaN  ...    0.000000   431.606161   9.015115
# 749973                   NaN  ...    0.379608   211.339385   7.358035
# 749974                   NaN  ...    0.000000    54.078307   5.591514
# 749975                   NaN  ...    0.014736  6466.967366  20.636253
# 749976                   NaN  ...    0.000000    98.213497   4.739605
# 749977                   NaN  ...    0.000000   298.083405   9.433318
# 749978                   NaN  ...    0.617260   691.948364   9.762471
# 749979                   NaN  ...    0.000000   126.060485   7.528584
# 749980                   NaN  ...    0.000000    87.733759  11.138093
# 749981                   NaN  ...    0.000000    65.896453   4.637678
# 749982                   NaN  ...    0.043477  5171.660856  13.032578
# 749983                   NaN  ...    0.212798    76.470610   5.402043
# 749984                   NaN  ...    0.151819   122.948454  10.372808
# 749985                   NaN  ...    0.000000   902.923959  14.211073
# 749986                   NaN  ...    0.000000   526.131813  10.078638
# 749987                   NaN  ...    0.129975   277.005968   8.370728
# 749988                   NaN  ...    0.091946   238.927881   8.731888
# 749989                   NaN  ...    0.000000   252.112295  13.635022
# 749990                   NaN  ...    0.000000    67.123637   5.808102
# 749991                   NaN  ...    0.000000   157.839792   6.471599
# 749992                   NaN  ...    0.000000   376.329059  13.997172
# 749993                   NaN  ...    0.414462   141.835838   7.678443
# 749994                   NaN  ...    0.796192   178.147605   6.590319
# 749995                   NaN  ...    0.000000    59.718773   9.629563
# 749996                   NaN  ...    0.000000   393.133456   8.605422
# 749997                   NaN  ...    0.000000   277.035589   7.687627
# 749998                   NaN  ...    0.759090   545.573365   9.945913
# 749999                   NaN  ...    0.047929   827.776775   9.368959
#
#         num_islands  num_pixel_in_shower  ph_charge_shower_max  \
# 0                 1                   12             11.641675
# 1                 1                   10             10.538471
# 2                 1                   15             38.462617
# 3                 2                   16             12.052377
# 4                 3                   21             18.281671
# 5                 1                   54             44.855807
# 6                 1                   12             12.666637
# 7                 2                   33             13.448519
# 8                 1                   20             13.346863
# 9                 1                   20             19.294325
# 10                1                   69             28.724806
# 11                1                   47             47.762357
# 12                1                   13             14.312603
# 13                1                   95             78.932777
# 14                3                  154            134.391160
# 15                1                  121             23.696084
# 16                1                   38             15.733755
# 17                1                   23             11.989486
# 18                1                   11             17.167481
# 19                1                   33             21.350228
# 20                3                  125             71.227725
# 21                1                   12             17.687827
# 22                2                   19             16.100071
# 23                1                   71             63.727892
# 24                2                   31             16.638484
# 25                1                   34             35.639481
# 26                1                   11             11.459308
# 27                1                   36             15.863282
# 28                2                   12              8.971458
# 29                1                   93             58.731659
# ...             ...                  ...                   ...
# 749970            2                   46             43.181052
# 749971            1                   34             19.758623
# 749972            1                   46             28.398651
# 749973            1                   19             27.070598
# 749974            2                   10              8.577257
# 749975            3                  321            187.159439
# 749976            2                   16             15.146364
# 749977            3                   41             17.573193
# 749978            2                   50             46.194747
# 749979            1                   15             21.072788
# 749980            1                   15              9.527101
# 749981            1                   10             11.463041
# 749982            2                  173            246.118185
# 749983            2                   13             10.644134
# 749984            2                   18             15.582473
# 749985            1                   80             48.537870
# 749986            1                   53             26.614119
# 749987            2                   41             13.402570
# 749988            1                   31             18.196879
# 749989            1                   30             19.762638
# 749990            2                   12             10.130630
# 749991            1                   19             23.559901
# 749992            1                   44             27.141761
# 749993            1                   16             13.931774
# 749994            1                   19             20.302583
# 749995            3                   10              9.122409
# 749996            1                   45             21.913469
# 749997            1                   29             24.178917
# 749998            2                   41             61.061699
# 749999            1                   56             50.500278
#
#         ph_charge_shower_mean  ph_charge_shower_min  \
# 0                    6.909483              3.352840
# 1                    6.146686              3.054085
columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d391559f7326> in <module>()
#       7     Tree = RandomForestClassifier(random_state=0, max_depth=14,
#       8         n_estimators=200, n_jobs=20,verbose=1)
# ----> 9     Tree.fit(X_train, y_train)
#      10     score = np.append(score, [[Tree.score(X_train,y_train)],[Tree.score(X_test,y_test)]], axis=1)
#
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if issparse(X):
#
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /opt/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
plt.plot(np.round(np.linspace(0,10,40),1),score[0])
plt.plot(np.round(np.linspace(0,10,40),1),score[1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b616224a30ad> in <module>()
# ----> 1 plt.plot(np.round(np.linspace(0,10,40),1),score[0])
#       2 plt.plot(np.round(np.linspace(0,10,40),1),score[1])
#       3 plt.show()
#
# /opt/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /opt/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /opt/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1422             kwargs['color'] = c
#    1423
# -> 1424         for line in self._get_lines(*args, **kwargs):
#    1425             self.add_line(line)
#    1426             lines.append(line)
#
# /opt/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     384                 return
#     385             if len(remaining) <= 3:
# --> 386                 for seg in self._plot_args(remaining, kwargs):
#     387                     yield seg
#     388                 return
#
# /opt/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     362             x, y = index_of(tup[-1])
#     363
# --> 364         x, y = self._xy_from_xy(x, y)
#     365
#     366         if self.command == 'plot':
#
# /opt/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     221         y = _check_1d(y)
#     222         if x.shape[0] != y.shape[0]:
# --> 223             raise ValueError("x and y must have same first dimension")
#     224         if x.ndim > 2 or y.ndim > 2:
#     225             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %%
print(score)
# Out:
# [[ 0.82565556  0.83032222  0.83413333  0.83782222  0.84142222  0.84518889
#    0.84898889  0.94765071  1.        ]
#  [ 0.80373333  0.8084      0.81278889  0.81755556  0.82248889  0.82648889
#    0.82945556  0.92739248  0.99966719]]

# %%
np.round(np.linspace(0,10,20), 2)
# Out:
# array([  0.  ,   0.53,   1.05,   1.58,   2.11,   2.63,   3.16,   3.68,
#          4.21,   4.74,   5.26,   5.79,   6.32,   6.84,   7.37,   7.89,
#          8.42,   8.95,   9.47,  10.  ])
